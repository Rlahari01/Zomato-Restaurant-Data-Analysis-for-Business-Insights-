# %%
import pandas as pd
import numpy as np
df=pd.read_csv(r"C:\Users\rlaha\OneDrive\Desktop\Zomato Dataset.csv")
#pd.set_option("display.max_rows",None)
df
# Out:
#            ID Delivery_person_ID  Delivery_person_Age  \
# 0      0xcdcd      DEHRES17DEL01                 36.0
# 1      0xd987      KOCRES16DEL01                 21.0
# 2      0x2784     PUNERES13DEL03                 23.0
# 3      0xc8b6     LUDHRES15DEL02                 34.0
# 4      0xdb64      KNPRES14DEL02                 24.0
# ...       ...                ...                  ...
# 45579  0x7c09      JAPRES04DEL01                 30.0
# 45580  0xd641      AGRRES16DEL01                 21.0
# 45581  0x4f8d     CHENRES08DEL03                 30.0
# 45582  0x5eee    COIMBRES11DEL01                 20.0
# 45583  0x5fb2   RANCHIRES09DEL02                 23.0
#
#        Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude  \
# 0                          4.2            30.327968             78.046106
# 1                          4.7            10.003064             76.307589
# 2                          4.7            18.562450             73.916619
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45584 entries, 0 to 45583
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           45584 non-null  object
#  1   Delivery_person_ID           45584 non-null  object
#  2   Delivery_person_Age          43730 non-null  float64
#  3   Delivery_person_Ratings      43676 non-null  float64
#  4   Restaurant_latitude          45584 non-null  float64
#  5   Restaurant_longitude         45584 non-null  float64
#  6   Delivery_location_latitude   45584 non-null  float64
#  7   Delivery_location_longitude  45584 non-null  float64
#  8   Order_Date                   45584 non-null  object
#  9   Time_Orderd                  43853 non-null  object
#  10  Time_Order_picked            45584 non-null  object
#  11  Weather_conditions           44968 non-null  object
# ...

# %%
df.ndim
# Out:
# 2

# %%
df.shape
# Out:
# (45584, 20)

# %%
df.size
# Out:
# 911680

# %%
df.dtypes
# Out:
# ID                              object
# Delivery_person_ID              object
# Delivery_person_Age            float64
# Delivery_person_Ratings        float64
# Restaurant_latitude            float64
# Restaurant_longitude           float64
# Delivery_location_latitude     float64
# Delivery_location_longitude    float64
# Order_Date                      object
# Time_Orderd                     object
# Time_Order_picked               object
# Weather_conditions              object
# Road_traffic_density            object
# Vehicle_condition                int64
# Type_of_order                   object
# Type_of_vehicle                 object
# multiple_deliveries            float64
# Festival                        object
# City                            object
# Time_taken (min)                 int64
# dtype: object

# %%
df.columns
# Out:
# Index(['ID', 'Delivery_person_ID', 'Delivery_person_Age',
#        'Delivery_person_Ratings', 'Restaurant_latitude',
#        'Restaurant_longitude', 'Delivery_location_latitude',
#        'Delivery_location_longitude', 'Order_Date', 'Time_Orderd',
#        'Time_Order_picked', 'Weather_conditions', 'Road_traffic_density',
#        'Vehicle_condition', 'Type_of_order', 'Type_of_vehicle',
#        'multiple_deliveries', 'Festival', 'City', 'Time_taken (min)'],
#       dtype='object')

# %%
df["Delivery_person_Age"].skew()
# Out:
# np.float64(0.018771873099854203)

# %%
df["Delivery_person_Ratings"].describe()
# Out:
# count    43676.000000
# mean         4.633774
# std          0.334744
# min          1.000000
# 25%          4.500000
# 50%          4.700000
# 75%          4.900000
# max          6.000000
# Name: Delivery_person_Ratings, dtype: float64

# %%
df["Delivery_person_Ratings"].skew()
# Out:
# np.float64(-2.4934024575465012)

# %%
df["Restaurant_latitude"].describe()
# Out:
# count    45584.000000
# mean        17.017948
# std          8.185674
# min        -30.905562
# 25%         12.933284
# 50%         18.551440
# 75%         22.728163
# max         30.914057
# Name: Restaurant_latitude, dtype: float64

# %%
df["Restaurant_latitude"].skew()
# Out:
# np.float64(-1.3616475133098918)

# %%
df["Restaurant_longitude"].describe()
# Out:
# count    45584.000000
# mean        70.229684
# std         22.885575
# min        -88.366217
# 25%         73.170000
# 50%         75.897963
# 75%         78.044095
# max         88.433452
# Name: Restaurant_longitude, dtype: float64

# %%
df["Restaurant_longitude"].skew()
# Out:
# np.float64(-3.2197783442111287)

# %%
df["Weather_conditions"].describe()
# Out:
# count     44968
# unique        6
# top         Fog
# freq       7653
# Name: Weather_conditions, dtype: object

# %%
df["Road_traffic_density"].describe()
# Out:
# count     44983
# unique        4
# top         Low
# freq      15476
# Name: Road_traffic_density, dtype: object

# %%
df["Type_of_order"].count()
# Out:
# np.int64(45584)

# %%
df["Order_Date"].count()
# Out:
# np.int64(45584)

# %%
df["Time_Orderd"].count()
# Out:
# np.int64(43853)

# %%
df["Time_Order_picked"].count()
# Out:
# np.int64(45584)

# %%
df["Vehicle_condition"].value_counts()
# Out:
# Vehicle_condition
# 2    15031
# 1    15028
# 0    15005
# 3      520
# Name: count, dtype: int64

# %%
df["multiple_deliveries"].value_counts()
# Out:
# multiple_deliveries
# 1.0    28151
# 0.0    14094
# 2.0     1985
# 3.0      361
# Name: count, dtype: int64

# %%
df["Vehicle_condition"].describe()
# Out:
# count    45584.000000
# mean         1.023385
# std          0.839055
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          2.000000
# max          3.000000
# Name: Vehicle_condition, dtype: float64

# %%
df["multiple_deliveries"].describe()
# Out:
# count    44591.000000
# mean         0.744635
# std          0.572510
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          1.000000
# max          3.000000
# Name: multiple_deliveries, dtype: float64

# %%
df["Vehicle_condition"].unique()
# Out:
# array([2, 1, 0, 3])

# %%
df["multiple_deliveries"].unique()
# Out:
# array([ 3.,  1.,  0., nan,  2.])

# %%
df["Type_of_order"].unique()
# Out:
# array(['Snack', 'Meal', 'Drinks', 'Buffet'], dtype=object)

# %%
df["Order_Date"].unique()
# Out:
# array(['12-02-2022', '13-02-2022', '04-03-2022', '14-02-2022',
#        '02-04-2022', '01-03-2022', '16-03-2022', '20-03-2022',
#        '15-02-2022', '10-03-2022', '11-03-2022', '27-03-2022',
#        '26-03-2022', '05-04-2022', '12-03-2022', '01-04-2022',
#        '05-03-2022', '11-02-2022', '08-03-2022', '03-04-2022',
#        '30-03-2022', '28-03-2022', '18-03-2022', '14-03-2022',
#        '06-04-2022', '04-04-2022', '24-03-2022', '19-03-2022',
#        '09-03-2022', '25-03-2022', '02-03-2022', '13-03-2022',
#        '29-03-2022', '31-03-2022', '17-03-2022', '07-03-2022',
#        '15-03-2022', '16-02-2022', '03-03-2022', '18-02-2022',
#        '23-03-2022', '17-02-2022', '06-03-2022', '21-03-2022'],
#       dtype=object)

# %%
df["Time_Orderd"].unique()
# Out:
# array(['21:55', '14:55', '17:30', '09:20', '19:50', '20:25', '20:30',
#        '20:40', '21:15', '20:20', '22:30', '08:15', '19:30', '12:25',
#        '18:35', '20:35', '23:20', '21:20', '23:35', '22:35', '23:25',
#        '13:35', '21:35', '18:55', '14:15', '0.458333333', '09:45',
#        '08:40', '0.958333333', '17:25', nan, '19:45', '19:10', '10:55',
#        '21:40', '0.791666667', '16:45', '11:30', '15:10', '22:45',
#        '22:10', '20:45', '22:50', '17:55', '09:25', '20:15', '22:25',
#        '22:40', '23:50', '15:25', '10:20', '20:55', '10:40', '15:55',
#        '20:10', '12:10', '15:30', '10:35', '21:10', '20:50', '12:35',
#        '0.875', '23:40', '18:15', '18:20', '11:45', '12:45', '23:30',
#        '10:50', '21:25', '10:10', '17:50', '22:20', '12:40', '23:55',
#        '10:25', '08:45', '23:45', '19:55', '22:15', '23:10', '09:15',
#        '18:25', '18:45', '16:50', '1', '14:20', '10:15', '08:50', '0.375',
# ...

# %%
df["Festival"].value_counts()
# Out:
# Festival
# No     44460
# Yes      896
# Name: count, dtype: int64

# %%
df["City"].value_counts()
# Out:
# City
# Metropolitian    34087
# Urban            10133
# Semi-Urban         164
# Name: count, dtype: int64

# %%
df["Time_taken (min)"].value_counts()
# Out:
# Time_taken (min)
# 26    2121
# 25    2050
# 27    1976
# 28    1965
# 29    1956
# 19    1824
# 15    1810
# 18    1765
# 16    1706
# 17    1696
# 24    1679
# 23    1643
# 20    1640
# 22    1626
# 21    1600
# 33    1258
# 30    1217
# 31    1213
# 34    1171
# 32    1123
# 38     887
# 36     852
# 39     847
# 35     832
# 37     828
# 11     757
# 10     750
# 12     746
# 14     739
# 13     716
# 43     567
# 42     561
# 40     554
# 44     553
# 41     553
# 47     295
# 49     280
# 48     277
# 46     274
# 45     241
# 53     100
# 51      94
# 54      91
# 52      79
# 50      72
# Name: count, dtype: int64

# %%
df["City"].unique()
# Out:
# array(['Metropolitian', 'Urban', 'Semi-Urban', nan], dtype=object)

# %%
df["Festival"].unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
df["Time_taken (min)"].unique()
# Out:
# array([46, 23, 21, 20, 41, 33, 40, 15, 36, 26, 39, 34, 18, 38, 47, 12, 22,
#        25, 35, 30, 10, 19, 11, 28, 52, 16, 27, 49, 24, 17, 14, 37, 44, 42,
#        31, 13, 29, 50, 43, 48, 32, 54, 53, 45, 51])

# %%
categorical=['Type_of_order', 'Type_of_vehicle','Festival', 'City']
print(df[categorical].value_counts())
df[categorical].nunique()
# Out:
# Type_of_order  Type_of_vehicle   Festival  City
# Meal           motorcycle        No        Metropolitian    4978
# Snack          motorcycle        No        Metropolitian    4894
# Buffet         motorcycle        No        Metropolitian    4834
# Drinks         motorcycle        No        Metropolitian    4749
#                scooter           No        Metropolitian    2774
#                                                             ...
# Meal           electric_scooter  Yes       Urban               1
#                scooter           Yes       Semi-Urban          1
#                                  No        Semi-Urban          1
# Snack          electric_scooter  No        Semi-Urban          1
#                scooter           Yes       Semi-Urban          1
# Name: count, Length: 75, dtype: int64
# Type_of_order      4
# Type_of_vehicle    4
# Festival           2
# City               3
# dtype: int64

# %%
continious=['Delivery_person_Age','Delivery_person_Ratings', 'Restaurant_latitude','Restaurant_longitude', 'Delivery_location_latitude','Delivery_location_longitude','Weather_conditions', 'Road_traffic_density']
print(df[continious].describe())
# Out:
#        Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# count         43730.000000             43676.000000         45584.000000
# mean             29.566911                 4.633774            17.017948
# std               5.815064                 0.334744             8.185674
# min              15.000000                 1.000000           -30.905562
# 25%              25.000000                 4.500000            12.933284
# 50%              30.000000                 4.700000            18.551440
# 75%              35.000000                 4.900000            22.728163
# max              50.000000                 6.000000            30.914057
#
#        Restaurant_longitude  Delivery_location_latitude  \
# count          45584.000000                45584.000000
# mean              70.229684                   17.465480
# std               22.885575                    7.335562
# min              -88.366217                    0.010000
# ...

# %%
categorical=['Delivery_person_Ratings', 'Type_of_vehicle','Festival', 'City']
print(df[categorical].value_counts())
df[categorical].nunique()
# Out:
# Delivery_person_Ratings  Type_of_vehicle  Festival  City
# 4.8                      motorcycle       No        Metropolitian    2936
# 4.6                      motorcycle       No        Metropolitian    2887
# 4.9                      motorcycle       No        Metropolitian    2873
# 4.7                      motorcycle       No        Metropolitian    2871
# 4.9                      scooter          No        Metropolitian    1778
#                                                                      ...
# 2.7                      scooter          No        Urban               1
# 2.6                      scooter          Yes       Metropolitian       1
# 4.9                      scooter          Yes       Semi-Urban          1
#                                                     Urban               1
# 6.0                      scooter          Yes       Metropolitian       1
# Name: count, Length: 280, dtype: int64
# Delivery_person_Ratings    28
# Type_of_vehicle             4
# ...

# %%
time=['Delivery_person_Ratings', 'Time_Orderd', 'Time_Order_picked']
print(df[time].value_counts())
df[time].nunique()
# Out:
# Delivery_person_Ratings  Time_Orderd  Time_Order_picked
# 4.7                      23:10        23:20                38
#                          23:30        23:45                38
#                          0.958333333  23:10                38
# 4.8                      18:25        18:40                36
# 4.9                      22:45        22:50                36
#                                                            ..
# 2.7                      23:30        23:40                 1
#                          23:25        23:35                 1
#                          23:20        23:25                 1
#                          23:10        23:20                 1
# 2.5                      22:55        23:05                 1
# Name: count, Length: 6061, dtype: int64
# Delivery_person_Ratings     28
# Time_Orderd                176
# Time_Order_picked          193
# dtype: int64

# %%
df=df[['Delivery_person_Age', 'Time_taken (min)']].dropna()
df
# Out:
#        Delivery_person_Age  Time_taken (min)
# 0                     36.0                46
# 1                     21.0                23
# 2                     23.0                21
# 3                     34.0                20
# 4                     24.0                41
# ...                    ...               ...
# 45579                 30.0                32
# 45580                 21.0                36
# 45581                 30.0                16
# 45582                 20.0                26
# 45583                 23.0                36
#
# [43730 rows x 2 columns]

# %%
df[['City', 'Festival']].value_counts()
# Out:
# City           Festival
# Metropolitian  No          33245
# Urban          No           9923
# Metropolitian  Yes           731
# Semi-Urban     No            123
# Urban          Yes           111
# Semi-Urban     Yes            41
# Name: count, dtype: int64

# %%
df.groupby(['Type_of_order', 'Type_of_vehicle']).size()
# Out:
# Type_of_order  Type_of_vehicle
# Buffet         bicycle               15
#                electric_scooter     943
#                motorcycle          6592
#                scooter             3727
# Drinks         bicycle               16
#                electric_scooter     949
#                motorcycle          6531
#                scooter             3825
# Meal           bicycle               23
#                electric_scooter     948
#                motorcycle          6656
#                scooter             3829
# Snack          bicycle               14
#                electric_scooter     974
#                motorcycle          6650
#                scooter             3892
# dtype: int64

# %%
pd.crosstab(df['City'], df['Festival'])
# Out:
# Festival          No  Yes
# City
# Metropolitian  33245  731
# Semi-Urban       123   41
# Urban           9923  111

# %%
df.groupby('Festival')['Time_taken (min)'].mean()
# Out:
# Festival
# No     25.984121
# Yes    45.517857
# Name: Time_taken (min), dtype: float64

# %%
df[['Type_of_order', 'City']].value_counts()
# Out:
# Type_of_order  City
# Meal           Metropolitian    8662
# Snack          Metropolitian    8565
# Drinks         Metropolitian    8435
# Buffet         Metropolitian    8425
# Snack          Urban            2575
# Drinks         Urban            2566
# Buffet         Urban            2507
# Meal           Urban            2485
# Snack          Semi-Urban         54
# Buffet         Semi-Urban         42
# Meal           Semi-Urban         34
# Drinks         Semi-Urban         34
# Name: count, dtype: int64

# %%
df[['Type_of_order', 'Festival']].value_counts()
# Out:
# Type_of_order  Festival
# Snack          No          11236
# Meal           No          11185
# Drinks         No          11039
# Buffet         No          11000
# Snack          Yes           243
# Drinks         Yes           219
# Buffet         Yes           218
# Meal           Yes           216
# Name: count, dtype: int64

# %%
df[['Type_of_order', 'Type_of_vehicle']].value_counts()
# Out:
# Type_of_order  Type_of_vehicle
# Meal           motorcycle          6656
# Snack          motorcycle          6650
# Buffet         motorcycle          6592
# Drinks         motorcycle          6531
# Snack          scooter             3892
# Meal           scooter             3829
# Drinks         scooter             3825
# Buffet         scooter             3727
# Snack          electric_scooter     974
# Drinks         electric_scooter     949
# Meal           electric_scooter     948
# Buffet         electric_scooter     943
# Meal           bicycle               23
# Drinks         bicycle               16
# Buffet         bicycle               15
# Snack          bicycle               14
# Name: count, dtype: int64

# %%
df[['Type_of_vehicle', 'Festival']].value_counts()
# Out:
# Type_of_vehicle   Festival
# motorcycle        No          25629
# scooter           No          15012
# electric_scooter  No           3753
# motorcycle        Yes           695
# scooter           Yes           161
# bicycle           No             66
# electric_scooter  Yes            38
# bicycle           Yes             2
# Name: count, dtype: int64

# %%
df.groupby(['Festival', 'Time_taken (min)']).size()
# Out:
# Festival  Time_taken (min)
# No        10                  659
#           11                  698
#           12                  704
#           13                  695
#           14                  724
#                              ...
# Yes       50                   18
#           51                   26
#           52                   21
#           53                   34
#           54                   37
# Length: 62, dtype: int64

# %%
df.groupby(['Type_of_vehicle', 'Time_taken (min)']).size()
# Out:
# Type_of_vehicle  Time_taken (min)
# bicycle          10                   1
#                  11                   1
#                  12                   2
#                  13                   1
#                  14                   2
#                                      ..
# scooter          48                  35
#                  49                  51
#                  50                   1
#                  52                   1
#                  54                   1
# Length: 161, dtype: int64

# %%
df.groupby('City')['Time_taken (min)'].mean()
# Out:
# City
# Metropolitian    27.314460
# Semi-Urban       49.731707
# Urban            22.983322
# Name: Time_taken (min), dtype: float64

# %%
df.groupby('Type_of_vehicle')['Time_taken (min)'].mean()
# Out:
# Type_of_vehicle
# bicycle             26.426471
# electric_scooter    24.470110
# motorcycle          27.605774
# scooter             24.478819
# Name: Time_taken (min), dtype: float64

# %%
df.groupby('Type_of_order')['Time_taken (min)'].mean()
# Out:
# Type_of_order
# Buffet    26.283320
# Drinks    26.187969
# Meal      26.417598
# Snack     26.285603
# Name: Time_taken (min), dtype: float64

# %%
df.groupby('City').size()
# Out:
# City
# Metropolitian    34087
# Semi-Urban         164
# Urban            10133
# dtype: int64

# %%
df.groupby('Type_of_vehicle')['Time_taken (min)'].agg(['mean', 'count'])
# Out:
#                        mean  count
# Type_of_vehicle
# bicycle           26.426471     68
# electric_scooter  24.470110   3814
# motorcycle        27.605774  26429
# scooter           24.478819  15273

# %%
import seaborn as sns
sns.histplot(x=df['Time_taken (min)'], bins=10)
# Out:
# <Axes: xlabel='Time_taken (min)', ylabel='Count'>

# %%
import seaborn as sns
print(sns.boxplot(x=df["Type_of_vehicle"]))
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %%
print(sns.boxplot(x=df["Weather_conditions"]))
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %%
sns.histplot(x=df["Type_of_order"],bins=7)
# Out:
# <Axes: xlabel='Type_of_order', ylabel='Count'>

# %%
sns.histplot(x=df["Time_Orderd"],bins=7)
# Out:
# <Axes: xlabel='Time_Orderd', ylabel='Count'>

# %%
sns.histplot(x=df["Time_Order_picked"],bins=7)
# Out:
# <Axes: xlabel='Time_Order_picked', ylabel='Count'>

# %%
sns.kdeplot(x=df["Time_taken (min)"])
# Out:
# <Axes: xlabel='Time_taken (min)', ylabel='Density'>

# %%
sns.kdeplot(x=df["multiple_deliveries"])
# Out:
# <Axes: xlabel='multiple_deliveries', ylabel='Density'>

# %%
sns.countplot(x=df["Delivery_person_Ratings"])
# Out:
# <Axes: xlabel='Delivery_person_Ratings', ylabel='count'>

# %%
sns.countplot(x=df["Road_traffic_density"])
# Out:
# <Axes: xlabel='Road_traffic_density', ylabel='count'>

# %%
import matplotlib.pyplot as plt
plt.hist(df["Type_of_vehicle"])
# Out:
# (array([26429.,     0.,     0., 15273.,     0.,     0.,  3814.,     0.,
#             0.,    68.]),
#  array([0. , 0.3, 0.6, 0.9, 1.2, 1.5, 1.8, 2.1, 2.4, 2.7, 3. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df["Time_taken (min)"])#,bins=8,range=(10000,80000))
# Out:
# (array([3708., 6977., 8333., 7826., 6351., 5236., 3116., 2475., 1126.,
#          436.]),
#  array([10. , 14.4, 18.8, 23.2, 27.6, 32. , 36.4, 40.8, 45.2, 49.6, 54. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.scatter(df["Type_of_vehicle"],df["multiple_deliveries"])

# %%
plt.plot(df["Type_of_order"],df["Time_taken (min)"],marker=0)

# %%
plt.scatter(x=df["Type_of_order"],y=df["Vehicle_condition"])
plt.xlabel("Type_of_ordert")
plt.ylabel("Vehicle_condition")
# Out:
# Text(0, 0.5, 'Vehicle_condition')
